# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../Data/ai and human generated text data.csv")

# %%
df
# Out:
#                                                     text  label
# 0      Got take-out. Very friendly staff, reasonable ...  Human
# 1      Love this bar! Fun crowd and the staff are all...  Human
# 2      After watching Whale Wars: Viking Shores, I ca...  Human
# 3      Kelly really wanted the new iPhone. She begged...  Human
# 4      Though this is the easiest way to secure a spo...  Human
# ...                                                  ...    ...
# 19995  Spaces is a startup with a team that specializ...     AI
# 19996  I was working at am plant for a temp agency. I...     AI
# 19997  is preparing himself to lift weigh and stands ...     AI
# 19998  I grew up knowing I wasn't quite right. I was ...     AI
# 19999  "Normal" (adj.) Conforming to the standard or ...     AI
#
# [20000 rows x 2 columns]

# %%
df["label"].value_counts()
# Out:
# label
# Human    10000
# AI       10000
# Name: count, dtype: int64

# %%
df['text_length'] = df['text'].apply(lambda x: len(x.split()))

# %%
df.groupby('label')['text_length'].describe()
# Out:
#          count     mean       std   min   25%   50%   75%   max
# label
# AI     10000.0  33.2644  3.214020  25.0  31.0  33.0  35.0  48.0
# Human  10000.0  31.3074  4.067427  25.0  28.0  31.0  34.0  46.0

# %%
import re

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

    # text = text.lower()
    # text = text.replace('\n', ' ')
    # return text

df['clean_text'] = df['text'].apply(clean_text)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# tfidf = TfidfVectorizer(
#     max_features=20000,
#     ngram_range=(1,2),
#     min_df=5,
#     max_df=0.9
# )
# # tfidf = TfidfVectorizer(
# #     analyzer='char',
# #     ngram_range=(3,5),
# #     min_df=5,
# #     max_features=30000
# # )

tfidf = TfidfVectorizer(
    max_features=20000,
    ngram_range=(1,2),
    min_df=5,
    max_df=0.9,
    sublinear_tf=True
)


X = tfidf.fit_transform(df['clean_text'])
y = df['label']


from sklearn.pipeline import FeatureUnion
from sklearn.feature_extraction.text import TfidfVectorizer

# word_tfidf = TfidfVectorizer(
#     max_features=20000,
#     ngram_range=(1,2),
#     min_df=5,
#     max_df=0.9
# )

# char_tfidf = TfidfVectorizer(
#     analyzer='char',
#     ngram_range=(3,5),
#     min_df=5,
#     max_features=30000
# )

# X = FeatureUnion([
#     ('word', word_tfidf),
#     ('char', char_tfidf)
# ]).fit_transform(df['clean_text'])
# y = df['label']

# %%
joblib.dump(tfidf, "../Models/tfidf_vectorizer.pkl")
# Out:
# ['../Models/tfidf_vectorizer.pkl']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
X_test, y_train
# Out:
# (<Compressed Sparse Row sparse matrix of dtype 'float64'
#  	with 146720 stored elements and shape (4000, 20000)>,
#  3500     Human
#  14606       AI
#  15079       AI
#  1798     Human
#  9966     Human
#           ...
#  7337     Human
#  5262     Human
#  4879     Human
#  10241       AI
#  13728       AI
#  Name: label, Length: 16000, dtype: object)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(X_test, y_test)
# Out:
# 0.75575

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB()
nb.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
nb.score(X_test, y_test)
# Out:
# 0.74975

# %%
from sklearn.svm import LinearSVC

svm = LinearSVC()
svm.fit(X_train, y_train)
# Out:
# LinearSVC()

# %%
svm.score(X_test, y_test)
# Out:
# 0.77725

# %%
from sklearn.metrics import confusion_matrix
y_pred = svm.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1617  383]
#  [ 508 1492]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])

plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(max_depth=10)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
tree.score(X_test, y_test)
# Out:
# 0.663

# %%
from sklearn.metrics import confusion_matrix
y_pred = tree.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1686  314]
#  [1034  966]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])

plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
import joblib
joblib.dump(lr, "../Models/logistic_regression.pkl")
joblib.dump(nb, "../Models/naive_bayes.pkl")
joblib.dump(svm, "../Models/LinearSVC.pkl")
# Out:
# ['../Models/LinearSVC.pkl']
